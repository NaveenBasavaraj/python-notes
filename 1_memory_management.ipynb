# %% [markdown]
# <a href="https://colab.research.google.com/github/NaveenBasavaraj/python-deep-drive/blob/main/1_memory_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Topics:
# 1. What are variables?
# 2. Memory management
# 3. Garbage Collection & Reference Counting
# 4. Dynamic Vs Static typing
# 5. Mutability vs Immutability
# 6. Shared References
# 7. Variable Equality
# 8. Python Optimizations and Interning
# 9. Everything is an Object

# %% [markdown]
# ## Memory Management:
#
# * We can think of memory as slots or boxes that exists in our computer
# * It can be accessed or retreived by using an address to that slot or box
# * An object stored in the memory may take more than one slot
# * Storing and retreiving objects is taken care by the **Python Memory Manager**
# ![image.png](data:image/png;base64,...)

# %%
# int object with value 10 is created in the memory
# my_var points to the address of the int object 10 in the memory
my_var = 10
print(id(my_var))
print(f"my_var references the object at {hex(id(my_var))} ")
# Out:
# 133890019164688
# my_var references the object at 0x79c5b3080210
